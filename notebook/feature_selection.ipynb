# %% [markdown]
# # Feature Selection
#
# The aim of this document is to provide an brief introduction to feature selection techniques and an example code and analysis.

# %%
from typing import *
from pathlib import Path

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display, HTML
plt.style.use("fivethirtyeight")

from pylab import rcParams
rcParams['figure.figsize'] = 14, 6

# %%
import warnings
warnings.filterwarnings("ignore") ## if lots of warnings are annoying you

# %%
import altair as alt

def adhoc_theme():
    theme_dict = {
        'config': {"view"      : {"height":400, "width":800 },
                   "title"     : {"fontSize":24, "fontWeight":"normal", "titleAlign":"center"},
                   "axisLeft"  : {"labelFontSize":14, "titleFontSize":16},
                   "axisRight" : {"labelFontSize":14, "titleFontSize":16},
                   "header"    : {"labelFontSize":14, "titleFontSize":16, "titleAlign":"left"},
                   "axisBottom": {"labelFontSize":14, "titleFontSize":16},
                   "legend"    : {"labelFontSize":12, "titleFontSize":14},
                   "range"     : {"category": {"scheme": "category10"}}
    }}
    return theme_dict

alt.themes.register("adhoc_theme", adhoc_theme)
alt.themes.enable("adhoc_theme");

alt.data_transformers.enable('default', max_rows=30000); ## needed for large data set

# %% [markdown]
# ## Data set
#
# The data set we use is [House Prices: Advanced Regression Techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques). The target variable is (logarithm of) the sale price. We remove two data points just after importing the data set because of the discussion [[1299, 524] considered harmful](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/discussion/105648).

# %%
import os
PROJ_ROOT = Path(os.getcwd()).parent
DATA_DIR = PROJ_ROOT / "data"
DATA_ZIP = DATA_DIR / "house-prices-advanced-regression-techniques.zip"

# %%
from zipfile import ZipFile
from sklearn.model_selection import train_test_split

with ZipFile(DATA_ZIP) as data_zip:
    with data_zip.open("train.csv","r") as fo:
        df_train = pd.read_csv(fo, index_col=0)
        
target = "SalePrice"
        
df_train.drop([524,1299], axis=0, inplace=True)
df_train, df_dev = train_test_split(df_train, test_size=0.3, random_state=1)
print("Training set size:", len(df_train))
print("dev set size     : ", len(df_dev))
# Out:
# Training set size: 1020
# dev set size     :  438

# %% [markdown]
# ## Data preprocessing
#
# Some part of our data processing is based on the notebook [stacked housing](https://www.kaggle.com/danielj6/stacked-housing).

# %% [markdown]
# ### Data fields
#
# Here's a brief version of what you'll find in the data description file.
#
# - SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# - MSSubClass: The building class
# - MSZoning: The general zoning classification
# - LotFrontage: Linear feet of street connected to property
# - LotArea: Lot size in square feet
# - Street: Type of road access
# - Alley: Type of alley access
# - LotShape: General shape of property
# - LandContour: Flatness of the property
# - Utilities: Type of utilities available
# - LotConfig: Lot configuration
# - LandSlope: Slope of property
# - Neighborhood: Physical locations within Ames city limits
# - Condition1: Proximity to main road or railroad
# - Condition2: Proximity to main road or railroad (if a second is present)
# - BldgType: Type of dwelling
# - HouseStyle: Style of dwelling
# - OverallQual: Overall material and finish quality
# - OverallCond: Overall condition rating
# - YearBuilt: Original construction date
# - YearRemodAdd: Remodel date
# - RoofStyle: Type of roof
# - RoofMatl: Roof material
# - Exterior1st: Exterior covering on house
# - Exterior2nd: Exterior covering on house (if more than one material)
# - MasVnrType: Masonry veneer type
# - MasVnrArea: Masonry veneer area in square feet
# - ExterQual: Exterior material quality
# - ExterCond: Present condition of the material on the exterior
# - Foundation: Type of foundation
# - BsmtQual: Height of the basement
# - BsmtCond: General condition of the basement
# - BsmtExposure: Walkout or garden level basement walls
# - BsmtFinType1: Quality of basement finished area
# - BsmtFinSF1: Type 1 finished square feet
# - BsmtFinType2: Quality of second finished area (if present)
# - BsmtFinSF2: Type 2 finished square feet
# - BsmtUnfSF: Unfinished square feet of basement area
# - TotalBsmtSF: Total square feet of basement area
# - Heating: Type of heating
# - HeatingQC: Heating quality and condition
# - CentralAir: Central air conditioning
# - Electrical: Electrical system
# - 1stFlrSF: First Floor square feet
# - 2ndFlrSF: Second floor square feet
# - LowQualFinSF: Low quality finished square feet (all floors)
# - GrLivArea: Above grade (ground) living area square feet
# - BsmtFullBath: Basement full bathrooms
# - BsmtHalfBath: Basement half bathrooms
# - FullBath: Full bathrooms above grade
# - HalfBath: Half baths above grade
# - Bedroom: Number of bedrooms above basement level
# - Kitchen: Number of kitchens
# - KitchenQual: Kitchen quality
# - TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# - Functional: Home functionality rating
# - Fireplaces: Number of fireplaces
# - FireplaceQu: Fireplace quality
# - GarageType: Garage location
# - GarageYrBlt: Year garage was built
# - GarageFinish: Interior finish of the garage
# - GarageCars: Size of garage in car capacity
# - GarageArea: Size of garage in square feet
# - GarageQual: Garage quality
# - GarageCond: Garage condition
# - PavedDrive: Paved driveway
# - WoodDeckSF: Wood deck area in square feet
# - OpenPorchSF: Open porch area in square feet
# - EnclosedPorch: Enclosed porch area in square feet
# - 3SsnPorch: Three season porch area in square feet
# - ScreenPorch: Screen porch area in square feet
# - PoolArea: Pool area in square feet
# - PoolQC: Pool quality
# - Fence: Fence quality
# - MiscFeature: Miscellaneous feature not covered in other categories
# - MiscVal: $Value of miscellaneous feature
# - MoSold: Month Sold
# - YrSold: Year Sold
# - SaleType: Type of sale
# - SaleCondition: Condition of sale

# %%
from adhoc.processing import Inspector

inspector_train = Inspector(df_train)

with pd.option_context("display.max_rows",None):
    display(inspector_train)
# Out:
#                  dtype  count_na   rate_na  n_unique  distinct     variable  \
# MSSubClass       int64         0  0.000000        15     False  categorical
# MSZoning        object         0  0.000000         5     False  categorical
# LotFrontage    float64       184  0.180392       103     False   continuous
# LotArea          int64         0  0.000000       796     False   continuous
# Street          object         0  0.000000         2     False       binary
# Alley           object       958  0.939216         2     False       binary
# LotShape        object         0  0.000000         4     False  categorical
# LandContour     object         0  0.000000         4     False  categorical
# Utilities       object         0  0.000000         2     False       binary
# LotConfig       object         0  0.000000         5     False  categorical
# LandSlope       object         0  0.000000         3     False  categorical
# Neighborhood    object         0  0.000000        25     False  categorical
# Condition1      object         0  0.000000         9     False  categorical
# Condition2      object         0  0.000000         6     False  categorical
# BldgType        object         0  0.000000         5     False  categorical
# HouseStyle      object         0  0.000000         8     False  categorical
# OverallQual      int64         0  0.000000        10     False  categorical
# OverallCond      int64         0  0.000000         8     False  categorical
# YearBuilt        int64         0  0.000000       107     False   continuous
# YearRemodAdd     int64         0  0.000000        61     False   continuous
# RoofStyle       object         0  0.000000         6     False  categorical
# RoofMatl        object         0  0.000000         6     False  categorical
# Exterior1st     object         0  0.000000        12     False  categorical
# Exterior2nd     object         0  0.000000        14     False  categorical
# MasVnrType      object         6  0.005882         4     False  categorical
# MasVnrArea     float64         6  0.005882       267     False   continuous
# ExterQual       object         0  0.000000         4     False  categorical
# ExterCond       object         0  0.000000         4     False  categorical
# Foundation      object         0  0.000000         6     False  categorical
# BsmtQual        object        26  0.025490         4     False  categorical
# BsmtCond        object        26  0.025490         4     False  categorical
# BsmtExposure    object        27  0.026471         4     False  categorical
# BsmtFinType1    object        26  0.025490         6     False  categorical
# BsmtFinSF1       int64         0  0.000000       499     False   continuous
# BsmtFinType2    object        27  0.026471         6     False  categorical
# BsmtFinSF2       int64         0  0.000000        99     False   continuous
# BsmtUnfSF        int64         0  0.000000       631     False   continuous
# TotalBsmtSF      int64         0  0.000000       585     False   continuous
# Heating         object         0  0.000000         5     False  categorical
# HeatingQC       object         0  0.000000         4     False  categorical
# CentralAir      object         0  0.000000         2     False       binary
# Electrical      object         1  0.000980         5     False  categorical
# 1stFlrSF         int64         0  0.000000       607     False   continuous
# 2ndFlrSF         int64         0  0.000000       312     False   continuous
# LowQualFinSF     int64         0  0.000000        17     False  categorical
# GrLivArea        int64         0  0.000000       669     False   continuous
# BsmtFullBath     int64         0  0.000000         4     False  categorical
# BsmtHalfBath     int64         0  0.000000         2     False       binary
# FullBath         int64         0  0.000000         4     False  categorical
# HalfBath         int64         0  0.000000         3     False  categorical
# BedroomAbvGr     int64         0  0.000000         7     False  categorical
# KitchenAbvGr     int64         0  0.000000         3     False  categorical
# KitchenQual     object         0  0.000000         4     False  categorical
# TotRmsAbvGrd     int64         0  0.000000        11     False  categorical
# Functional      object         0  0.000000         7     False  categorical
# Fireplaces       int64         0  0.000000         4     False  categorical
# FireplaceQu     object       495  0.485294         5     False  categorical
# GarageType      object        46  0.045098         6     False  categorical
# GarageYrBlt    float64        46  0.045098        96     False   continuous
# GarageFinish    object        46  0.045098         3     False  categorical
# GarageCars       int64         0  0.000000         5     False  categorical
# GarageArea       int64         0  0.000000       367     False   continuous
# GarageQual      object        46  0.045098         5     False  categorical
# GarageCond      object        46  0.045098         5     False  categorical
# PavedDrive      object         0  0.000000         3     False  categorical
# WoodDeckSF       int64         0  0.000000       220     False   continuous
# OpenPorchSF      int64         0  0.000000       172     False   continuous
# EnclosedPorch    int64         0  0.000000        91     False   continuous
# 3SsnPorch        int64         0  0.000000        12     False  categorical
# ScreenPorch      int64         0  0.000000        57     False   continuous
# PoolArea         int64         0  0.000000         5     False  categorical
# PoolQC          object      1016  0.996078         2     False       binary
# Fence           object       823  0.806863         4     False  categorical
# MiscFeature     object       984  0.964706         3     False  categorical
# MiscVal          int64         0  0.000000        18     False  categorical
# MoSold           int64         0  0.000000        12     False  categorical
# YrSold           int64         0  0.000000         5     False  categorical
# SaleType        object         0  0.000000         9     False  categorical
# SaleCondition   object         0  0.000000         6     False  categorical
# SalePrice        int64         0  0.000000       531     False   continuous
#
#               sample_value
# MSSubClass             160
# MSZoning                FV
# LotFrontage             89
# LotArea               9636
# Street                Pave
# Alley                 Grvl
# LotShape               IR1
# LandContour            Low
# Utilities           AllPub
# LotConfig           Corner
# LandSlope              Mod
# Neighborhood       ClearCr
# Condition1            PosN
# Condition2            Norm
# BldgType            TwnhsE
# HouseStyle          2.5Fin
# OverallQual              4
# OverallCond              7
# YearBuilt             1947
# YearRemodAdd          1974
# RoofStyle             Shed
# RoofMatl           Tar&Grv
# Exterior1st        HdBoard
# Exterior2nd        Wd Shng
# MasVnrType          BrkCmn
# MasVnrArea             147
# ExterQual               Gd
# ExterCond               TA
# Foundation            Slab
# BsmtQual                Fa
# BsmtCond                Po
# BsmtExposure            Av
# BsmtFinType1           GLQ
# BsmtFinSF1             226
# BsmtFinType2           LwQ
# BsmtFinSF2             823
# BsmtUnfSF              312
# TotalBsmtSF           1234
# Heating               Grav
# HeatingQC               Ex
# CentralAir               N
# Electrical           SBrkr
# 1stFlrSF               664
# 2ndFlrSF               454
# LowQualFinSF             0
# GrLivArea             1634
# BsmtFullBath             1
# BsmtHalfBath             0
# FullBath                 2
# HalfBath                 1
# BedroomAbvGr             6
# KitchenAbvGr             2
# KitchenQual             Fa
# TotRmsAbvGrd             8
# Functional            Min1
# Fireplaces               2
# FireplaceQu             TA
# GarageType         Basment
# GarageYrBlt           1957
# GarageFinish           Fin
# GarageCars               2
# GarageArea             788
# GarageQual              Ex
# GarageCond              Po
# PavedDrive               Y
# WoodDeckSF              78
# OpenPorchSF             66
# EnclosedPorch          189
# 3SsnPorch              216
# ScreenPorch            126
# PoolArea               512
# PoolQC                  Ex
# Fence                MnPrv
# MiscFeature           Othr
# MiscVal                500
# MoSold                   2
# YrSold                2007
# SaleType             ConLI
# SaleCondition      Partial
# SalePrice            81000

# %% [markdown]
# ### Data type correction
#
# Some categorical values are described as numbers in the data set so that they look like continuous variables. For example `MSSubClass` (the building class).

# %%
def correct_dtype(data:pd.DataFrame) -> pd.DataFrame:
    df = data.copy()
    df["MSSubClass"] = df["MSSubClass"].apply(lambda x: f"C{x:03d}")
    df["MoSold"] = df["MoSold"].apply(lambda x: f"M{x:02d}")
    
    ## YearBuilt (Original construction date), YearRemodAdd (Remodel date) and YrSold (Year Sold)
    ## Instead we use differences.
    df["Age"] = df["YrSold"] - df["YearBuilt"]
    df["AgeAfterRemod"] = df["YrSold"] - df["YearRemodAdd"]
    
    ## Apply the same idea to GarageYrBlt
    df["GarageAge"] = df["YrSold"] - df["GarageYrBlt"]
    
    df.drop(["YearBuilt","YearRemodAdd","YrSold", "GarageYrBlt"], axis=1, inplace=True)    
    
    ## only four houses have a pool
    df["hasPool"] = df["PoolArea"].apply(lambda x: 1 if x > 0 else 0)
    df.drop("hasPool", axis=1, inplace=True)

    return df

# %%
df_train = correct_dtype(df_train)
df_dev = correct_dtype(df_dev)

inspector_train = Inspector(df_train)

# %% [markdown]
# ### Missing values

# %%
inspector_train.result.query("count_na > 0").sort_values(by="count_na", ascending=False)
# Out:
#                 dtype  count_na   rate_na  n_unique  distinct     variable  \
# PoolQC         object      1016  0.996078         2     False       binary
# MiscFeature    object       984  0.964706         3     False  categorical
# Alley          object       958  0.939216         2     False       binary
# Fence          object       823  0.806863         4     False  categorical
# FireplaceQu    object       495  0.485294         5     False  categorical
# LotFrontage   float64       184  0.180392       103     False   continuous
# GarageCond     object        46  0.045098         5     False  categorical
# GarageQual     object        46  0.045098         5     False  categorical
# GarageFinish   object        46  0.045098         3     False  categorical
# GarageType     object        46  0.045098         6     False  categorical
# GarageAge     float64        46  0.045098       100     False   continuous
# BsmtFinType2   object        27  0.026471         6     False  categorical
# BsmtExposure   object        27  0.026471         4     False  categorical
# BsmtFinType1   object        26  0.025490         6     False  categorical
# BsmtCond       object        26  0.025490         4     False  categorical
# BsmtQual       object        26  0.025490         4     False  categorical
# MasVnrArea    float64         6  0.005882       267     False   continuous
# MasVnrType     object         6  0.005882         4     False  categorical
# Electrical     object         1  0.000980         5     False  categorical
#
#              sample_value
# PoolQC                 Gd
# MiscFeature          Shed
# Alley                Pave
# Fence                GdWo
# FireplaceQu            Fa
# LotFrontage           144
# GarageCond             Ex
# GarageQual             Ex
# GarageFinish          Fin
# GarageType         2Types
# GarageAge             100
# BsmtFinType2          Rec
# BsmtExposure           No
# BsmtFinType1          Unf
# BsmtCond               TA
# BsmtQual               Ex
# MasVnrArea            140
# MasVnrType         BrkCmn
# Electrical          SBrkr

# %%
## badly filled columns 
badly_filled_columns = inspector_train.result.query("rate_na > 0.4").index.tolist()

## remove badly filled columns
df_train.drop(badly_filled_columns, axis=1, inplace=True)
df_dev.drop(badly_filled_columns, axis=1, inplace=True)

## update Inspector instance
inspector_train = Inspector(df_train)

## columns which are removed
badly_filled_columns
# Out:
# ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
with pd.option_context("display.max_rows",None):
    display(inspector_train)
# Out:
#                  dtype  count_na   rate_na  n_unique  distinct     variable  \
# MSSubClass      object         0  0.000000        15     False  categorical
# MSZoning        object         0  0.000000         5     False  categorical
# LotFrontage    float64       184  0.180392       103     False   continuous
# LotArea          int64         0  0.000000       796     False   continuous
# Street          object         0  0.000000         2     False       binary
# LotShape        object         0  0.000000         4     False  categorical
# LandContour     object         0  0.000000         4     False  categorical
# Utilities       object         0  0.000000         2     False       binary
# LotConfig       object         0  0.000000         5     False  categorical
# LandSlope       object         0  0.000000         3     False  categorical
# Neighborhood    object         0  0.000000        25     False  categorical
# Condition1      object         0  0.000000         9     False  categorical
# Condition2      object         0  0.000000         6     False  categorical
# BldgType        object         0  0.000000         5     False  categorical
# HouseStyle      object         0  0.000000         8     False  categorical
# OverallQual      int64         0  0.000000        10     False  categorical
# OverallCond      int64         0  0.000000         8     False  categorical
# RoofStyle       object         0  0.000000         6     False  categorical
# RoofMatl        object         0  0.000000         6     False  categorical
# Exterior1st     object         0  0.000000        12     False  categorical
# Exterior2nd     object         0  0.000000        14     False  categorical
# MasVnrType      object         6  0.005882         4     False  categorical
# MasVnrArea     float64         6  0.005882       267     False   continuous
# ExterQual       object         0  0.000000         4     False  categorical
# ExterCond       object         0  0.000000         4     False  categorical
# Foundation      object         0  0.000000         6     False  categorical
# BsmtQual        object        26  0.025490         4     False  categorical
# BsmtCond        object        26  0.025490         4     False  categorical
# BsmtExposure    object        27  0.026471         4     False  categorical
# BsmtFinType1    object        26  0.025490         6     False  categorical
# BsmtFinSF1       int64         0  0.000000       499     False   continuous
# BsmtFinType2    object        27  0.026471         6     False  categorical
# BsmtFinSF2       int64         0  0.000000        99     False   continuous
# BsmtUnfSF        int64         0  0.000000       631     False   continuous
# TotalBsmtSF      int64         0  0.000000       585     False   continuous
# Heating         object         0  0.000000         5     False  categorical
# HeatingQC       object         0  0.000000         4     False  categorical
# CentralAir      object         0  0.000000         2     False       binary
# Electrical      object         1  0.000980         5     False  categorical
# 1stFlrSF         int64         0  0.000000       607     False   continuous
# 2ndFlrSF         int64         0  0.000000       312     False   continuous
# LowQualFinSF     int64         0  0.000000        17     False  categorical
# GrLivArea        int64         0  0.000000       669     False   continuous
# BsmtFullBath     int64         0  0.000000         4     False  categorical
# BsmtHalfBath     int64         0  0.000000         2     False       binary
# FullBath         int64         0  0.000000         4     False  categorical
# HalfBath         int64         0  0.000000         3     False  categorical
# BedroomAbvGr     int64         0  0.000000         7     False  categorical
# KitchenAbvGr     int64         0  0.000000         3     False  categorical
# KitchenQual     object         0  0.000000         4     False  categorical
# TotRmsAbvGrd     int64         0  0.000000        11     False  categorical
# Functional      object         0  0.000000         7     False  categorical
# Fireplaces       int64         0  0.000000         4     False  categorical
# GarageType      object        46  0.045098         6     False  categorical
# GarageFinish    object        46  0.045098         3     False  categorical
# GarageCars       int64         0  0.000000         5     False  categorical
# GarageArea       int64         0  0.000000       367     False   continuous
# GarageQual      object        46  0.045098         5     False  categorical
# GarageCond      object        46  0.045098         5     False  categorical
# PavedDrive      object         0  0.000000         3     False  categorical
# WoodDeckSF       int64         0  0.000000       220     False   continuous
# OpenPorchSF      int64         0  0.000000       172     False   continuous
# EnclosedPorch    int64         0  0.000000        91     False   continuous
# 3SsnPorch        int64         0  0.000000        12     False  categorical
# ScreenPorch      int64         0  0.000000        57     False   continuous
# PoolArea         int64         0  0.000000         5     False  categorical
# MiscVal          int64         0  0.000000        18     False  categorical
# MoSold          object         0  0.000000        12     False  categorical
# SaleType        object         0  0.000000         9     False  categorical
# SaleCondition   object         0  0.000000         6     False  categorical
# SalePrice        int64         0  0.000000       531     False   continuous
# Age              int64         0  0.000000       116     False   continuous
# AgeAfterRemod    int64         0  0.000000        61     False   continuous
# GarageAge      float64        46  0.045098       100     False   continuous
#
#               sample_value
# MSSubClass            C090
# MSZoning                RL
# LotFrontage             61
# LotArea               8993
# Street                Grvl
# LotShape               IR2
# LandContour            Low
# Utilities           NoSeWa
# LotConfig           Corner
# LandSlope              Sev
# Neighborhood       StoneBr
# Condition1            PosA
# Condition2            Norm
# BldgType             Twnhs
# HouseStyle          2.5Fin
# OverallQual              4
# OverallCond              8
# RoofStyle          Mansard
# RoofMatl              Roll
# Exterior1st        CemntBd
# Exterior2nd        AsbShng
# MasVnrType            None
# MasVnrArea             340
# ExterQual               Gd
# ExterCond               TA
# Foundation            Slab
# BsmtQual                Ex
# BsmtCond                Fa
# BsmtExposure            Av
# BsmtFinType1           Unf
# BsmtFinSF1             204
# BsmtFinType2           Rec
# BsmtFinSF2             168
# BsmtUnfSF             1652
# TotalBsmtSF           1051
# Heating               GasA
# HeatingQC               Gd
# CentralAir               N
# Electrical             Mix
# 1stFlrSF              1269
# 2ndFlrSF               299
# LowQualFinSF            53
# GrLivArea             1344
# BsmtFullBath             2
# BsmtHalfBath             1
# FullBath                 3
# HalfBath                 0
# BedroomAbvGr             2
# KitchenAbvGr             2
# KitchenQual             TA
# TotRmsAbvGrd             7
# Functional            Maj2
# Fireplaces               1
# GarageType          Detchd
# GarageFinish           Unf
# GarageCars               2
# GarageArea             690
# GarageQual              Fa
# GarageCond              Ex
# PavedDrive               N
# WoodDeckSF             392
# OpenPorchSF             48
# EnclosedPorch          220
# 3SsnPorch              508
# ScreenPorch            287
# PoolArea               512
# MiscVal                500
# MoSold                 M07
# SaleType               New
# SaleCondition       Alloca
# SalePrice           156000
# Age                    102
# AgeAfterRemod           29
# GarageAge               25

# %% [markdown]
# ## Feature selection with statistical tests
#
# We can check whether a feature is statistically significant to the target variable. If it is not the case, then we might drop the feature from the data set.
#
# Since our target variable is continuous, we perform the following two types of (non-parametric) statistical tests.
#
# - For categorical feature (such as `SaleType`): **one-way ANOVA on ranks**
#   - Null-hypothesis: The medians of the target variable in the categories are the same.
# - For continuous feature (such as `GarageArea`): **Speaman correlation**
#   - Null-hypothesis: The feature variable is not correlated to the target variable.
#
# Advantages:
#
# - We can compute the $p$-values just after simple preprocessing.
# - The huge number of observations (rows) hardly ever matters.
# - The huge number of features (columns) hardly ever matters, neither.
#
# Disadvantages:
#
# - The $p$-values are not suitable for a ranking. Only for a screening.
#   - The $p$-value measures how small/large the difference is under the null-hypothesis. (The $p$-value is small => the difference is large.)
# - We ignore the possibility that the feature is important under a certain combination with another feature.

# %%
## Actually we should apply this method after imputation.
## Because this is just demonstration and we do not use the result,
## we just drop rows with a missing values and the field "Utilities",
## which is constant because of dropping missing values.

df_na_dropped = df_train.dropna(how="any").drop("Utilities", axis=1)
inspector_na_dropped = Inspector(df_na_dropped)

with pd.option_context("display.max_rows", None):
    display(inspector_na_dropped.significance_test_features(target).sort_values(by="pval"))
# Out:
#            field1     field2                    test  statistic          pval
# 41      GrLivArea  SalePrice    Spearman correlation   0.738739  9.93213e-134
# 14    OverallQual  SalePrice  one-way ANOVA on ranks    530.291  2.21866e-109
# 69            Age  SalePrice    Spearman correlation  -0.652921   9.47956e-95
# 55     GarageArea  SalePrice    Spearman correlation   0.651784   2.55902e-94
# 33    TotalBsmtSF  SalePrice    Spearman correlation   0.640129   5.31438e-90
# 25       BsmtQual  SalePrice  one-way ANOVA on ranks    404.453   2.40226e-87
# 38       1stFlrSF  SalePrice    Spearman correlation    0.62759   1.46558e-85
# 9    Neighborhood  SalePrice  one-way ANOVA on ranks    472.418    8.7376e-85
# 48    KitchenQual  SalePrice  one-way ANOVA on ranks    376.495   2.72914e-81
# 22      ExterQual  SalePrice  one-way ANOVA on ranks    374.711    6.6459e-81
# 54     GarageCars  SalePrice  one-way ANOVA on ranks    368.672    1.3498e-79
# 44       FullBath  SalePrice  one-way ANOVA on ranks    368.135   1.76474e-79
# 71      GarageAge  SalePrice    Spearman correlation  -0.602087   3.95107e-77
# 70  AgeAfterRemod  SalePrice    Spearman correlation  -0.601397    6.5205e-77
# 53   GarageFinish  SalePrice  one-way ANOVA on ranks    296.328       4.5e-65
# 24     Foundation  SalePrice  one-way ANOVA on ranks    263.192   9.35496e-56
# 60    OpenPorchSF  SalePrice    Spearman correlation    0.51044   2.57456e-52
# 49   TotRmsAbvGrd  SalePrice  one-way ANOVA on ranks    258.875   1.33149e-50
# 0      MSSubClass  SalePrice  one-way ANOVA on ranks    275.196   1.71991e-50
# 52     GarageType  SalePrice  one-way ANOVA on ranks    241.277   4.08607e-50
# 3         LotArea  SalePrice    Spearman correlation   0.490855    6.2036e-48
# 35      HeatingQC  SalePrice  one-way ANOVA on ranks    214.489   3.11793e-46
# 51     Fireplaces  SalePrice  one-way ANOVA on ranks    208.527    6.0617e-45
# 28   BsmtFinType1  SalePrice  one-way ANOVA on ranks    196.553    1.5514e-40
# 21     MasVnrArea  SalePrice    Spearman correlation   0.435118   6.52786e-37
# 18    Exterior1st  SalePrice  one-way ANOVA on ranks     197.36   2.62397e-36
# 1        MSZoning  SalePrice  one-way ANOVA on ranks    166.273   6.59505e-35
# 2     LotFrontage  SalePrice    Spearman correlation   0.419832   3.14114e-34
# 19    Exterior2nd  SalePrice  one-way ANOVA on ranks    192.822   4.05417e-34
# 20     MasVnrType  SalePrice  one-way ANOVA on ranks    147.202    1.0576e-31
# 59     WoodDeckSF  SalePrice    Spearman correlation   0.371173   1.46388e-26
# 15    OverallCond  SalePrice  one-way ANOVA on ranks     126.74   3.01315e-24
# 5        LotShape  SalePrice  one-way ANOVA on ranks    108.851   1.93918e-23
# 68  SaleCondition  SalePrice  one-way ANOVA on ranks    103.621   1.66607e-21
# 27   BsmtExposure  SalePrice  one-way ANOVA on ranks     91.608   9.88893e-20
# 67       SaleType  SalePrice  one-way ANOVA on ranks    104.657   1.17503e-19
# 45       HalfBath  SalePrice  one-way ANOVA on ranks    75.9921   3.15152e-17
# 36     CentralAir  SalePrice  one-way ANOVA on ranks    59.8383   1.02977e-14
# 29     BsmtFinSF1  SalePrice    Spearman correlation    0.26734   4.55536e-14
# 13     HouseStyle  SalePrice  one-way ANOVA on ranks    76.8173   6.12714e-14
# 39       2ndFlrSF  SalePrice    Spearman correlation   0.245783   4.66294e-12
# 37     Electrical  SalePrice  one-way ANOVA on ranks     58.772   5.25418e-12
# 61  EnclosedPorch  SalePrice    Spearman correlation  -0.242562   8.97743e-12
# 46   BedroomAbvGr  SalePrice  one-way ANOVA on ranks    57.9133   1.19324e-10
# 42   BsmtFullBath  SalePrice  one-way ANOVA on ranks    39.7384   2.34919e-09
# 58     PavedDrive  SalePrice  one-way ANOVA on ranks    37.4377   7.42182e-09
# 26       BsmtCond  SalePrice  one-way ANOVA on ranks    39.0982   1.65445e-08
# 57     GarageCond  SalePrice  one-way ANOVA on ranks    35.2884   4.05287e-07
# 32      BsmtUnfSF  SalePrice    Spearman correlation   0.180624   4.52262e-07
# 12       BldgType  SalePrice  one-way ANOVA on ranks    32.0144   1.90017e-06
# 56     GarageQual  SalePrice  one-way ANOVA on ranks    25.9436   3.24841e-05
# 16      RoofStyle  SalePrice  one-way ANOVA on ranks    25.2184   4.54693e-05
# 7       LotConfig  SalePrice  one-way ANOVA on ranks    21.5648   0.000244624
# 47   KitchenAbvGr  SalePrice  one-way ANOVA on ranks    15.6509   0.000399434
# 50     Functional  SalePrice  one-way ANOVA on ranks    21.1366    0.00076331
# 10     Condition1  SalePrice  one-way ANOVA on ranks    26.0598    0.00102583
# 6     LandContour  SalePrice  one-way ANOVA on ranks    15.8204    0.00123428
# 63    ScreenPorch  SalePrice    Spearman correlation   0.110459    0.00214401
# 23      ExterCond  SalePrice  one-way ANOVA on ranks    14.0508    0.00283687
# 4          Street  SalePrice  one-way ANOVA on ranks     7.6004    0.00583553
# 17       RoofMatl  SalePrice  one-way ANOVA on ranks    13.4921     0.0191785
# 31     BsmtFinSF2  SalePrice    Spearman correlation -0.0779789     0.0304946
# 11     Condition2  SalePrice  one-way ANOVA on ranks    10.5785     0.0317327
# 43   BsmtHalfBath  SalePrice  one-way ANOVA on ranks    4.53868     0.0331372
# 65        MiscVal  SalePrice  one-way ANOVA on ranks    20.0928     0.0929204
# 30   BsmtFinType2  SalePrice  one-way ANOVA on ranks    8.92996      0.111891
# 66         MoSold  SalePrice  one-way ANOVA on ranks    15.8444      0.147005
# 40   LowQualFinSF  SalePrice  one-way ANOVA on ranks    16.0386      0.189475
# 64       PoolArea  SalePrice  one-way ANOVA on ranks    3.96725      0.265022
# 34        Heating  SalePrice  one-way ANOVA on ranks    2.44424      0.294605
# 8       LandSlope  SalePrice  one-way ANOVA on ranks   0.380222      0.826867
# 62      3SsnPorch  SalePrice  one-way ANOVA on ranks    1.84846       0.98531

# %% [markdown]
# ## ML Pipeline

# %%
def separate_x_y(data:pd.DataFrame) -> Tuple[pd.DataFrame, pd.Series]:
    X = data.drop(target, axis=1)
    y = np.log1p(data[target]).rename("LogSalePrice")
    return X, y

X_train, y_train = separate_x_y(df_train)
X_dev, y_dev = separate_x_y(df_dev)

# %% [markdown]
# ### Filling missing values
#
# Some columns describe extra information about another column. For example `FireplaceQu`. This column describes a fireplace and therefore the column is filled if (and only if) `Fireplaces` is not zero. `Bsmt`, the abbreviation of "basement", is used as part of feature names. These features are missing if the house has no basement.
#
# - NA means 'NA': `BsmtCond`, `BsmtExposure`, `BsmtFinType1`, `BsmtFinType2`, `BsmtQual`,
#   `GarageCond`, `GarageFinish`, `GarageQual`, `GarageType`,  `MasVnrType`
# - NA means 0: `GarageArea`, `MasVnrArea`
# - NA means 'unknown': `Electrical`, `GarageYrBuilt` (or `GarageAge`)

# %%
inspector_train.result.query("count_na > 0").sort_index()
# Out:
#                 dtype  count_na   rate_na  n_unique  distinct     variable  \
# BsmtCond       object        26  0.025490         4     False  categorical
# BsmtExposure   object        27  0.026471         4     False  categorical
# BsmtFinType1   object        26  0.025490         6     False  categorical
# BsmtFinType2   object        27  0.026471         6     False  categorical
# BsmtQual       object        26  0.025490         4     False  categorical
# Electrical     object         1  0.000980         5     False  categorical
# GarageAge     float64        46  0.045098       100     False   continuous
# GarageCond     object        46  0.045098         5     False  categorical
# GarageFinish   object        46  0.045098         3     False  categorical
# GarageQual     object        46  0.045098         5     False  categorical
# GarageType     object        46  0.045098         6     False  categorical
# LotFrontage   float64       184  0.180392       103     False   continuous
# MasVnrArea    float64         6  0.005882       267     False   continuous
# MasVnrType     object         6  0.005882         4     False  categorical
#
#              sample_value
# BsmtCond               Fa
# BsmtExposure           Av
# BsmtFinType1          Unf
# BsmtFinType2          Rec
# BsmtQual               Ex
# Electrical            Mix
# GarageAge              25
# GarageCond             Ex
# GarageFinish          Unf
# GarageQual             Fa
# GarageType         Detchd
# LotFrontage            61
# MasVnrArea            340
# MasVnrType           None

# %%
cols_na_is_na = ["BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2", "BsmtQual", 
                   "GarageCond", "GarageFinish", "GarageQual", "GarageType", "MasVnrType"]
cols_na_is_zero = ["LotFrontage", "GarageArea", "MasVnrArea"]
cols_na_is_unknown = ["Electrical"]
cols_median_fills_na = ["GarageAge"]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

imputer = ColumnTransformer([
    ("NA", SimpleImputer(strategy="constant", fill_value="NA"), cols_na_is_na),
    ("Zero", SimpleImputer(strategy="constant", fill_value=0), cols_na_is_zero),
    ("Unknown", SimpleImputer(strategy="constant", fill_value="unknown"), cols_na_is_unknown),
    ("Median", SimpleImputer(strategy="median"), cols_median_fills_na)
], remainder="passthrough")

# %%
## check if the imputer works expectedly

cols_with_na = cols_na_is_na + cols_na_is_zero + cols_na_is_unknown + cols_median_fills_na
cols_without_na = [col for col in X_train.columns if col not in cols_with_na]
columns_after_imputation = cols_with_na + cols_without_na
pd.DataFrame(imputer.fit_transform(X_train), columns=columns_after_imputation)
# Out:
#      BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual GarageCond  \
# 0          Gd           Gd          Unf          Unf       Gd         TA
# 1          NA           NA           NA           NA       NA         TA
# 2          TA           No          GLQ          Rec       TA         TA
# 3          Fa           No          Unf          Unf       TA         NA
# 4          TA           No          Unf          Unf       Ex         TA
# ...       ...          ...          ...          ...      ...        ...
# 1015       TA           No          Unf          Unf       TA         TA
# 1016       TA           No          GLQ          Unf       Gd         TA
# 1017       TA           No          Unf          Unf       Gd         TA
# 1018       TA           No          ALQ          Unf       TA         TA
# 1019       TA           No          Unf          Unf       TA         TA
#
#      GarageFinish GarageQual GarageType MasVnrType  ... EnclosedPorch  \
# 0             Fin         TA    BuiltIn    BrkFace  ...             0
# 1             Unf         TA     Detchd       None  ...             0
# 2             Unf         TA     Attchd    BrkFace  ...             0
# 3              NA         NA         NA       None  ...           100
# 4             Fin         TA     Attchd       None  ...             0
# ...           ...        ...        ...        ...  ...           ...
# 1015          Unf         TA     Detchd       None  ...           143
# 1016          RFn         TA     Attchd      Stone  ...             0
# 1017          RFn         TA     Attchd       None  ...           137
# 1018          Unf         TA     Detchd    BrkFace  ...             0
# 1019          Unf         TA     Detchd       None  ...             0
#
#      3SsnPorch ScreenPorch PoolArea MiscVal MoSold SaleType SaleCondition  \
# 0            0           0        0       0    M02       WD        Normal
# 1            0           0        0       0    M04       WD        Normal
# 2            0           0        0       0    M07       WD        Normal
# 3            0           0        0       0    M01       WD        Normal
# 4            0           0        0       0    M05      New       Partial
# ...        ...         ...      ...     ...    ...      ...           ...
# 1015         0           0        0       0    M07       WD        Normal
# 1016         0           0        0       0    M06       WD        Normal
# 1017         0           0        0       0    M10       WD        Normal
# 1018         0           0        0       0    M08       WD        Normal
# 1019         0           0        0       0    M09       WD        Normal
#
#       Age AgeAfterRemod
# 0       2             1
# 1      55             3
# 2      42             8
# 3      86            58
# 4       1             0
# ...   ...           ...
# 1015  117             9
# 1016    1             1
# 1017   21            21
# 1018   37            37
# 1019  107            57
#
# [1020 rows x 73 columns]

# %% [markdown]
# ### Encoding of categorical variables
#
# #### Ordinal variable
#
# Some categorical variables can be ordered. For example `ExterQual`, `BsmtQual`, `KitchenQual` and `GarageQual` have values `Po` (Poor), `Fa` (Fair), `TA` (Average/Typical), `Gd` (Good), `Ex` (Excellent). (The detailed description of labels can be found `data_description.txt`.) Such a variable should be regarded as an ordered variable.
#
# #### Nominal variable
#
# We just apply an ordinary one hot encoder to the nominal variables.

# %%
def names2indices(names:str) -> List[int]:
    """
    Because after imputation there is no column names available,
    we need a function which converts a list of (original) column
    names into the 
    
    global variable
    columns_after_imputation
    """
    return [i for i,name in enumerate(columns_after_imputation) if name in names]

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

col_quality = ["BsmtCond", "BsmtQual", "ExterCond", "ExterQual", 
               "GarageCond", "GarageQual", "HeatingQC", "KitchenQual"]
col_ordered = col_quality + ["LandSlope", "BsmtExposure", "GarageFinish"]
col_nominal = [cat for cat in inspector_train.get_cats() if cat not in col_ordered]

encoder = ColumnTransformer([
    ("Quality", 
     OrdinalEncoder(categories=[["NA","Po","Fa","TA","Gd","Ex"]]*len(col_quality)), 
     names2indices(col_quality)),
    ("LandSlope", 
     OrdinalEncoder(categories=[["Gtl","Mod","Sev"]]), 
     names2indices(["LandSlope"])),
    ("BsmtExposure", 
     OrdinalEncoder(categories=[["NA", "No", "Mn", "Av", "Gd"]]), 
     names2indices(["BsmtExposure"])),
    ("GarageFinish", 
     OrdinalEncoder(categories=[["NA", "Unf", "RFn", "Fin"]]), 
     names2indices(["GarageFinish"])),
    ("Nominal",
     OneHotEncoder(handle_unknown="ignore", sparse=False), 
     names2indices(col_nominal))],
    remainder='passthrough')

encoder.fit(imputer.fit_transform(X_train));

# %%
def generate_names_from_ohe(names:List[str], one_hot_encoder:OneHotEncoder) -> List[str]:
    column_names = []
    for name, cats in zip(names, one_hot_encoder.categories_):
        column_names.extend([f"{name}_{cat}" for cat in cats])
    return column_names

# %%
## columns after encoding 

columns_after_encoding = col_ordered
columns_after_encoding.extend(generate_names_from_ohe(col_nominal, encoder.transformers_[-2][1]))
columns_after_encoding.extend([col for col in columns_after_imputation if col not in col_ordered+col_nominal])
len(columns_after_encoding)
# Out:
# 352

# %%
df_after_encoding = pd.DataFrame(encoder.transform(imputer.transform(X_train)).astype(np.float),
                                 columns=columns_after_encoding,
                                 index=X_train.index)
inspector_after_encoding = Inspector(df_after_encoding)

with pd.option_context("display.max_rows", None):
    display(inspector_after_encoding)
# Out:
#                          dtype  count_na  rate_na  n_unique  distinct  \
# BsmtCond               float64         0      0.0         5     False
# BsmtQual               float64         0      0.0         5     False
# ExterCond              float64         0      0.0         6     False
# ExterQual              float64         0      0.0         6     False
# GarageCond             float64         0      0.0         4     False
# GarageQual             float64         0      0.0         4     False
# HeatingQC              float64         0      0.0         4     False
# KitchenQual            float64         0      0.0         4     False
# LandSlope              float64         0      0.0         3     False
# BsmtExposure           float64         0      0.0         5     False
# GarageFinish           float64         0      0.0         4     False
# MSSubClass_ALQ         float64         0      0.0         2     False
# MSSubClass_BLQ         float64         0      0.0         2     False
# MSSubClass_GLQ         float64         0      0.0         2     False
# MSSubClass_LwQ         float64         0      0.0         2     False
# MSSubClass_NA          float64         0      0.0         2     False
# MSSubClass_Rec         float64         0      0.0         2     False
# MSSubClass_Unf         float64         0      0.0         2     False
# MSZoning_ALQ           float64         0      0.0         2     False
# MSZoning_BLQ           float64         0      0.0         2     False
# MSZoning_GLQ           float64         0      0.0         2     False
# MSZoning_LwQ           float64         0      0.0         2     False
# MSZoning_NA            float64         0      0.0         2     False
# MSZoning_Rec           float64         0      0.0         2     False
# MSZoning_Unf           float64         0      0.0         2     False
# Street_2Types          float64         0      0.0         2     False
# Street_Attchd          float64         0      0.0         2     False
# Street_Basment         float64         0      0.0         2     False
# Street_BuiltIn         float64         0      0.0         2     False
# Street_CarPort         float64         0      0.0         2     False
# Street_Detchd          float64         0      0.0         2     False
# Street_NA              float64         0      0.0         2     False
# LotShape_BrkCmn        float64         0      0.0         2     False
# LotShape_BrkFace       float64         0      0.0         2     False
# LotShape_NA            float64         0      0.0         2     False
# LotShape_None          float64         0      0.0         2     False
# LotShape_Stone         float64         0      0.0         2     False
# LandContour_FuseA      float64         0      0.0         2     False
# LandContour_FuseF      float64         0      0.0         2     False
# LandContour_FuseP      float64         0      0.0         2     False
# LandContour_Mix        float64         0      0.0         2     False
# LandContour_SBrkr      float64         0      0.0         2     False
# LandContour_unknown    float64         0      0.0         2     False
# Utilities_C020         float64         0      0.0         2     False
# Utilities_C030         float64         0      0.0         2     False
# Utilities_C040         float64         0      0.0         2     False
# Utilities_C045         float64         0      0.0         2     False
# Utilities_C050         float64         0      0.0         2     False
# Utilities_C060         float64         0      0.0         2     False
# Utilities_C070         float64         0      0.0         2     False
# Utilities_C075         float64         0      0.0         2     False
# Utilities_C080         float64         0      0.0         2     False
# Utilities_C085         float64         0      0.0         2     False
# Utilities_C090         float64         0      0.0         2     False
# Utilities_C120         float64         0      0.0         2     False
# Utilities_C160         float64         0      0.0         2     False
# Utilities_C180         float64         0      0.0         2     False
# Utilities_C190         float64         0      0.0         2     False
# LotConfig_C (all)      float64         0      0.0         2     False
# LotConfig_FV           float64         0      0.0         2     False
# LotConfig_RH           float64         0      0.0         2     False
# LotConfig_RL           float64         0      0.0         2     False
# LotConfig_RM           float64         0      0.0         2     False
# Neighborhood_Grvl      float64         0      0.0         2     False
# Neighborhood_Pave      float64         0      0.0         2     False
# Condition1_IR1         float64         0      0.0         2     False
# Condition1_IR2         float64         0      0.0         2     False
# Condition1_IR3         float64         0      0.0         2     False
# Condition1_Reg         float64         0      0.0         2     False
# Condition2_Bnk         float64         0      0.0         2     False
# Condition2_HLS         float64         0      0.0         2     False
# Condition2_Low         float64         0      0.0         2     False
# Condition2_Lvl         float64         0      0.0         2     False
# BldgType_AllPub        float64         0      0.0         2     False
# BldgType_NoSeWa        float64         0      0.0         2     False
# HouseStyle_Corner      float64         0      0.0         2     False
# HouseStyle_CulDSac     float64         0      0.0         2     False
# HouseStyle_FR2         float64         0      0.0         2     False
# HouseStyle_FR3         float64         0      0.0         2     False
# HouseStyle_Inside      float64         0      0.0         2     False
# OverallQual_Blmngtn    float64         0      0.0         2     False
# OverallQual_Blueste    float64         0      0.0         2     False
# OverallQual_BrDale     float64         0      0.0         2     False
# OverallQual_BrkSide    float64         0      0.0         2     False
# OverallQual_ClearCr    float64         0      0.0         2     False
# OverallQual_CollgCr    float64         0      0.0         2     False
# OverallQual_Crawfor    float64         0      0.0         2     False
# OverallQual_Edwards    float64         0      0.0         2     False
# OverallQual_Gilbert    float64         0      0.0         2     False
# OverallQual_IDOTRR     float64         0      0.0         2     False
# OverallQual_MeadowV    float64         0      0.0         2     False
# OverallQual_Mitchel    float64         0      0.0         2     False
# OverallQual_NAmes      float64         0      0.0         2     False
# OverallQual_NPkVill    float64         0      0.0         2     False
# OverallQual_NWAmes     float64         0      0.0         2     False
# OverallQual_NoRidge    float64         0      0.0         2     False
# OverallQual_NridgHt    float64         0      0.0         2     False
# OverallQual_OldTown    float64         0      0.0         2     False
# OverallQual_SWISU      float64         0      0.0         2     False
# OverallQual_Sawyer     float64         0      0.0         2     False
# OverallQual_SawyerW    float64         0      0.0         2     False
# OverallQual_Somerst    float64         0      0.0         2     False
# OverallQual_StoneBr    float64         0      0.0         2     False
# OverallQual_Timber     float64         0      0.0         2     False
# OverallQual_Veenker    float64         0      0.0         2     False
# OverallCond_Artery     float64         0      0.0         2     False
# OverallCond_Feedr      float64         0      0.0         2     False
# OverallCond_Norm       float64         0      0.0         2     False
# OverallCond_PosA       float64         0      0.0         2     False
# OverallCond_PosN       float64         0      0.0         2     False
# OverallCond_RRAe       float64         0      0.0         2     False
# OverallCond_RRAn       float64         0      0.0         2     False
# OverallCond_RRNe       float64         0      0.0         2     False
# OverallCond_RRNn       float64         0      0.0         2     False
# RoofStyle_Artery       float64         0      0.0         2     False
# RoofStyle_Feedr        float64         0      0.0         2     False
# RoofStyle_Norm         float64         0      0.0         2     False
# RoofStyle_PosA         float64         0      0.0         2     False
# RoofStyle_RRAn         float64         0      0.0         2     False
# RoofStyle_RRNn         float64         0      0.0         2     False
# RoofMatl_1Fam          float64         0      0.0         2     False
# RoofMatl_2fmCon        float64         0      0.0         2     False
# RoofMatl_Duplex        float64         0      0.0         2     False
# RoofMatl_Twnhs         float64         0      0.0         2     False
# RoofMatl_TwnhsE        float64         0      0.0         2     False
# Exterior1st_1.5Fin     float64         0      0.0         2     False
# Exterior1st_1.5Unf     float64         0      0.0         2     False
# Exterior1st_1Story     float64         0      0.0         2     False
# Exterior1st_2.5Fin     float64         0      0.0         2     False
# Exterior1st_2.5Unf     float64         0      0.0         2     False
# Exterior1st_2Story     float64         0      0.0         2     False
# Exterior1st_SFoyer     float64         0      0.0         2     False
# Exterior1st_SLvl       float64         0      0.0         2     False
# Exterior2nd_1          float64         0      0.0         2     False
# Exterior2nd_2          float64         0      0.0         2     False
# Exterior2nd_3          float64         0      0.0         2     False
# Exterior2nd_4          float64         0      0.0         2     False
# Exterior2nd_5          float64         0      0.0         2     False
# Exterior2nd_6          float64         0      0.0         2     False
# Exterior2nd_7          float64         0      0.0         2     False
# Exterior2nd_8          float64         0      0.0         2     False
# Exterior2nd_9          float64         0      0.0         2     False
# Exterior2nd_10         float64         0      0.0         2     False
# MasVnrType_2           float64         0      0.0         2     False
# MasVnrType_3           float64         0      0.0         2     False
# MasVnrType_4           float64         0      0.0         2     False
# MasVnrType_5           float64         0      0.0         2     False
# MasVnrType_6           float64         0      0.0         2     False
# MasVnrType_7           float64         0      0.0         2     False
# MasVnrType_8           float64         0      0.0         2     False
# MasVnrType_9           float64         0      0.0         2     False
# Foundation_Flat        float64         0      0.0         2     False
# Foundation_Gable       float64         0      0.0         2     False
# Foundation_Gambrel     float64         0      0.0         2     False
# Foundation_Hip         float64         0      0.0         2     False
# Foundation_Mansard     float64         0      0.0         2     False
# Foundation_Shed        float64         0      0.0         2     False
# BsmtFinType1_CompShg   float64         0      0.0         2     False
# BsmtFinType1_Membran   float64         0      0.0         2     False
# BsmtFinType1_Roll      float64         0      0.0         2     False
# BsmtFinType1_Tar&Grv   float64         0      0.0         2     False
# BsmtFinType1_WdShake   float64         0      0.0         2     False
# BsmtFinType1_WdShngl   float64         0      0.0         2     False
# BsmtFinType2_AsbShng   float64         0      0.0         2     False
# BsmtFinType2_BrkComm   float64         0      0.0         2     False
# BsmtFinType2_BrkFace   float64         0      0.0         2     False
# BsmtFinType2_CemntBd   float64         0      0.0         2     False
# BsmtFinType2_HdBoard   float64         0      0.0         2     False
# BsmtFinType2_MetalSd   float64         0      0.0         2     False
# BsmtFinType2_Plywood   float64         0      0.0         2     False
# BsmtFinType2_Stone     float64         0      0.0         2     False
# BsmtFinType2_Stucco    float64         0      0.0         2     False
# BsmtFinType2_VinylSd   float64         0      0.0         2     False
# BsmtFinType2_Wd Sdng   float64         0      0.0         2     False
# BsmtFinType2_WdShing   float64         0      0.0         2     False
# Heating_AsbShng        float64         0      0.0         2     False
# Heating_Brk Cmn        float64         0      0.0         2     False
# Heating_BrkFace        float64         0      0.0         2     False
# Heating_CmentBd        float64         0      0.0         2     False
# Heating_HdBoard        float64         0      0.0         2     False
# Heating_ImStucc        float64         0      0.0         2     False
# Heating_MetalSd        float64         0      0.0         2     False
# Heating_Other          float64         0      0.0         2     False
# Heating_Plywood        float64         0      0.0         2     False
# Heating_Stone          float64         0      0.0         2     False
# Heating_Stucco         float64         0      0.0         2     False
# Heating_VinylSd        float64         0      0.0         2     False
# Heating_Wd Sdng        float64         0      0.0         2     False
# Heating_Wd Shng        float64         0      0.0         2     False
# CentralAir_BrkTil      float64         0      0.0         2     False
# CentralAir_CBlock      float64         0      0.0         2     False
# CentralAir_PConc       float64         0      0.0         2     False
# CentralAir_Slab        float64         0      0.0         2     False
# CentralAir_Stone       float64         0      0.0         2     False
# CentralAir_Wood        float64         0      0.0         2     False
# Electrical_Floor       float64         0      0.0         2     False
# Electrical_GasA        float64         0      0.0         2     False
# Electrical_GasW        float64         0      0.0         2     False
# Electrical_Grav        float64         0      0.0         2     False
# Electrical_Wall        float64         0      0.0         2     False
# LowQualFinSF_N         float64         0      0.0         2     False
# LowQualFinSF_Y         float64         0      0.0         2     False
# BsmtFullBath_0         float64         0      0.0         2     False
# BsmtFullBath_53        float64         0      0.0         2     False
# BsmtFullBath_80        float64         0      0.0         2     False
# BsmtFullBath_120       float64         0      0.0         2     False
# BsmtFullBath_144       float64         0      0.0         2     False
# BsmtFullBath_156       float64         0      0.0         2     False
# BsmtFullBath_234       float64         0      0.0         2     False
# BsmtFullBath_360       float64         0      0.0         2     False
# BsmtFullBath_384       float64         0      0.0         2     False
# BsmtFullBath_390       float64         0      0.0         2     False
# BsmtFullBath_392       float64         0      0.0         2     False
# BsmtFullBath_397       float64         0      0.0         2     False
# BsmtFullBath_473       float64         0      0.0         2     False
# BsmtFullBath_481       float64         0      0.0         2     False
# BsmtFullBath_514       float64         0      0.0         2     False
# BsmtFullBath_528       float64         0      0.0         2     False
# BsmtFullBath_572       float64         0      0.0         2     False
# BsmtHalfBath_0         float64         0      0.0         2     False
# BsmtHalfBath_1         float64         0      0.0         2     False
# BsmtHalfBath_2         float64         0      0.0         2     False
# BsmtHalfBath_3         float64         0      0.0         2     False
# FullBath_0             float64         0      0.0         2     False
# FullBath_1             float64         0      0.0         2     False
# HalfBath_0             float64         0      0.0         2     False
# HalfBath_1             float64         0      0.0         2     False
# HalfBath_2             float64         0      0.0         2     False
# HalfBath_3             float64         0      0.0         2     False
# BedroomAbvGr_0         float64         0      0.0         2     False
# BedroomAbvGr_1         float64         0      0.0         2     False
# BedroomAbvGr_2         float64         0      0.0         2     False
# KitchenAbvGr_0         float64         0      0.0         2     False
# KitchenAbvGr_1         float64         0      0.0         2     False
# KitchenAbvGr_2         float64         0      0.0         2     False
# KitchenAbvGr_3         float64         0      0.0         2     False
# KitchenAbvGr_4         float64         0      0.0         2     False
# KitchenAbvGr_5         float64         0      0.0         2     False
# KitchenAbvGr_6         float64         0      0.0         2     False
# TotRmsAbvGrd_1         float64         0      0.0         2     False
# TotRmsAbvGrd_2         float64         0      0.0         2     False
# TotRmsAbvGrd_3         float64         0      0.0         2     False
# Functional_2           float64         0      0.0         2     False
# Functional_3           float64         0      0.0         2     False
# Functional_4           float64         0      0.0         2     False
# Functional_5           float64         0      0.0         2     False
# Functional_6           float64         0      0.0         2     False
# Functional_7           float64         0      0.0         2     False
# Functional_8           float64         0      0.0         2     False
# Functional_9           float64         0      0.0         2     False
# Functional_10          float64         0      0.0         2     False
# Functional_11          float64         0      0.0         2     False
# Functional_12          float64         0      0.0         2     False
# Fireplaces_Maj1        float64         0      0.0         2     False
# Fireplaces_Maj2        float64         0      0.0         2     False
# Fireplaces_Min1        float64         0      0.0         2     False
# Fireplaces_Min2        float64         0      0.0         2     False
# Fireplaces_Mod         float64         0      0.0         2     False
# Fireplaces_Sev         float64         0      0.0         2     False
# Fireplaces_Typ         float64         0      0.0         2     False
# GarageType_0           float64         0      0.0         2     False
# GarageType_1           float64         0      0.0         2     False
# GarageType_2           float64         0      0.0         2     False
# GarageType_3           float64         0      0.0         2     False
# GarageCars_0           float64         0      0.0         2     False
# GarageCars_1           float64         0      0.0         2     False
# GarageCars_2           float64         0      0.0         2     False
# GarageCars_3           float64         0      0.0         2     False
# GarageCars_4           float64         0      0.0         2     False
# PavedDrive_N           float64         0      0.0         2     False
# PavedDrive_P           float64         0      0.0         2     False
# PavedDrive_Y           float64         0      0.0         2     False
# 3SsnPorch_0            float64         0      0.0         2     False
# 3SsnPorch_96           float64         0      0.0         2     False
# 3SsnPorch_140          float64         0      0.0         2     False
# 3SsnPorch_144          float64         0      0.0         2     False
# 3SsnPorch_168          float64         0      0.0         2     False
# 3SsnPorch_180          float64         0      0.0         2     False
# 3SsnPorch_216          float64         0      0.0         2     False
# 3SsnPorch_238          float64         0      0.0         2     False
# 3SsnPorch_290          float64         0      0.0         2     False
# 3SsnPorch_320          float64         0      0.0         2     False
# 3SsnPorch_407          float64         0      0.0         2     False
# 3SsnPorch_508          float64         0      0.0         2     False
# PoolArea_0             float64         0      0.0         2     False
# PoolArea_512           float64         0      0.0         2     False
# PoolArea_555           float64         0      0.0         2     False
# PoolArea_576           float64         0      0.0         2     False
# PoolArea_738           float64         0      0.0         2     False
# MiscVal_0              float64         0      0.0         2     False
# MiscVal_54             float64         0      0.0         2     False
# MiscVal_350            float64         0      0.0         2     False
# MiscVal_400            float64         0      0.0         2     False
# MiscVal_450            float64         0      0.0         2     False
# MiscVal_480            float64         0      0.0         2     False
# MiscVal_500            float64         0      0.0         2     False
# MiscVal_560            float64         0      0.0         2     False
# MiscVal_600            float64         0      0.0         2     False
# MiscVal_620            float64         0      0.0         2     False
# MiscVal_700            float64         0      0.0         2     False
# MiscVal_800            float64         0      0.0         2     False
# MiscVal_1150           float64         0      0.0         2     False
# MiscVal_1200           float64         0      0.0         2     False
# MiscVal_1300           float64         0      0.0         2     False
# MiscVal_2000           float64         0      0.0         2     False
# MiscVal_3500           float64         0      0.0         2     False
# MiscVal_15500          float64         0      0.0         2     False
# MoSold_M01             float64         0      0.0         2     False
# MoSold_M02             float64         0      0.0         2     False
# MoSold_M03             float64         0      0.0         2     False
# MoSold_M04             float64         0      0.0         2     False
# MoSold_M05             float64         0      0.0         2     False
# MoSold_M06             float64         0      0.0         2     False
# MoSold_M07             float64         0      0.0         2     False
# MoSold_M08             float64         0      0.0         2     False
# MoSold_M09             float64         0      0.0         2     False
# MoSold_M10             float64         0      0.0         2     False
# MoSold_M11             float64         0      0.0         2     False
# MoSold_M12             float64         0      0.0         2     False
# SaleType_COD           float64         0      0.0         2     False
# SaleType_CWD           float64         0      0.0         2     False
# SaleType_Con           float64         0      0.0         2     False
# SaleType_ConLD         float64         0      0.0         2     False
# SaleType_ConLI         float64         0      0.0         2     False
# SaleType_ConLw         float64         0      0.0         2     False
# SaleType_New           float64         0      0.0         2     False
# SaleType_Oth           float64         0      0.0         2     False
# SaleType_WD            float64         0      0.0         2     False
# SaleCondition_Abnorml  float64         0      0.0         2     False
# SaleCondition_AdjLand  float64         0      0.0         2     False
# SaleCondition_Alloca   float64         0      0.0         2     False
# SaleCondition_Family   float64         0      0.0         2     False
# SaleCondition_Normal   float64         0      0.0         2     False
# SaleCondition_Partial  float64         0      0.0         2     False
# LotFrontage            float64         0      0.0       104     False
# GarageArea             float64         0      0.0       367     False
# MasVnrArea             float64         0      0.0       267     False
# GarageAge              float64         0      0.0       100     False
# LotArea                float64         0      0.0       796     False
# BsmtFinSF1             float64         0      0.0       499     False
# BsmtFinSF2             float64         0      0.0        99     False
# BsmtUnfSF              float64         0      0.0       631     False
# TotalBsmtSF            float64         0      0.0       585     False
# 1stFlrSF               float64         0      0.0       607     False
# 2ndFlrSF               float64         0      0.0       312     False
# GrLivArea              float64         0      0.0       669     False
# WoodDeckSF             float64         0      0.0       220     False
# OpenPorchSF            float64         0      0.0       172     False
# EnclosedPorch          float64         0      0.0        91     False
# ScreenPorch            float64         0      0.0        57     False
# Age                    float64         0      0.0       116     False
# AgeAfterRemod          float64         0      0.0        61     False
#
#                           variable  sample_value
# BsmtCond               categorical           3.0
# BsmtQual               categorical           3.0
# ExterCond              categorical           5.0
# ExterQual              categorical           2.0
# GarageCond             categorical           4.0
# GarageQual             categorical           5.0
# HeatingQC              categorical           4.0
# KitchenQual            categorical           2.0
# LandSlope              categorical           2.0
# BsmtExposure           categorical           0.0
# GarageFinish           categorical           3.0
# MSSubClass_ALQ              binary           1.0
# MSSubClass_BLQ              binary           0.0
# MSSubClass_GLQ              binary           0.0
# MSSubClass_LwQ              binary           0.0
# MSSubClass_NA               binary           1.0
# MSSubClass_Rec              binary           1.0
# MSSubClass_Unf              binary           1.0
# MSZoning_ALQ                binary           1.0
# MSZoning_BLQ                binary           1.0
# MSZoning_GLQ                binary           0.0
# MSZoning_LwQ                binary           1.0
# MSZoning_NA                 binary           1.0
# MSZoning_Rec                binary           0.0
# MSZoning_Unf                binary           0.0
# Street_2Types               binary           1.0
# Street_Attchd               binary           1.0
# Street_Basment              binary           1.0
# Street_BuiltIn              binary           0.0
# Street_CarPort              binary           1.0
# Street_Detchd               binary           0.0
# Street_NA                   binary           1.0
# LotShape_BrkCmn             binary           1.0
# LotShape_BrkFace            binary           0.0
# LotShape_NA                 binary           1.0
# LotShape_None               binary           1.0
# LotShape_Stone              binary           0.0
# LandContour_FuseA           binary           1.0
# LandContour_FuseF           binary           0.0
# LandContour_FuseP           binary           0.0
# LandContour_Mix             binary           0.0
# LandContour_SBrkr           binary           1.0
# LandContour_unknown         binary           1.0
# Utilities_C020              binary           1.0
# Utilities_C030              binary           0.0
# Utilities_C040              binary           1.0
# Utilities_C045              binary           1.0
# Utilities_C050              binary           1.0
# Utilities_C060              binary           0.0
# Utilities_C070              binary           0.0
# Utilities_C075              binary           1.0
# Utilities_C080              binary           0.0
# Utilities_C085              binary           0.0
# Utilities_C090              binary           0.0
# Utilities_C120              binary           0.0
# Utilities_C160              binary           1.0
# Utilities_C180              binary           1.0
# Utilities_C190              binary           0.0
# LotConfig_C (all)           binary           0.0
# LotConfig_FV                binary           1.0
# LotConfig_RH                binary           0.0
# LotConfig_RL                binary           1.0
# LotConfig_RM                binary           0.0
# Neighborhood_Grvl           binary           1.0
# Neighborhood_Pave           binary           1.0
# Condition1_IR1              binary           1.0
# Condition1_IR2              binary           0.0
# Condition1_IR3              binary           1.0
# Condition1_Reg              binary           1.0
# Condition2_Bnk              binary           1.0
# Condition2_HLS              binary           1.0
# Condition2_Low              binary           0.0
# Condition2_Lvl              binary           0.0
# BldgType_AllPub             binary           1.0
# BldgType_NoSeWa             binary           1.0
# HouseStyle_Corner           binary           0.0
# HouseStyle_CulDSac          binary           0.0
# HouseStyle_FR2              binary           0.0
# HouseStyle_FR3              binary           1.0
# HouseStyle_Inside           binary           0.0
# OverallQual_Blmngtn         binary           1.0
# OverallQual_Blueste         binary           0.0
# OverallQual_BrDale          binary           1.0
# OverallQual_BrkSide         binary           1.0
# OverallQual_ClearCr         binary           1.0
# OverallQual_CollgCr         binary           1.0
# OverallQual_Crawfor         binary           0.0
# OverallQual_Edwards         binary           1.0
# OverallQual_Gilbert         binary           1.0
# OverallQual_IDOTRR          binary           1.0
# OverallQual_MeadowV         binary           1.0
# OverallQual_Mitchel         binary           1.0
# OverallQual_NAmes           binary           0.0
# OverallQual_NPkVill         binary           1.0
# OverallQual_NWAmes          binary           1.0
# OverallQual_NoRidge         binary           0.0
# OverallQual_NridgHt         binary           1.0
# OverallQual_OldTown         binary           1.0
# OverallQual_SWISU           binary           0.0
# OverallQual_Sawyer          binary           0.0
# OverallQual_SawyerW         binary           1.0
# OverallQual_Somerst         binary           0.0
# OverallQual_StoneBr         binary           1.0
# OverallQual_Timber          binary           1.0
# OverallQual_Veenker         binary           0.0
# OverallCond_Artery          binary           1.0
# OverallCond_Feedr           binary           0.0
# OverallCond_Norm            binary           1.0
# OverallCond_PosA            binary           0.0
# OverallCond_PosN            binary           0.0
# OverallCond_RRAe            binary           0.0
# OverallCond_RRAn            binary           0.0
# OverallCond_RRNe            binary           0.0
# OverallCond_RRNn            binary           1.0
# RoofStyle_Artery            binary           1.0
# RoofStyle_Feedr             binary           0.0
# RoofStyle_Norm              binary           1.0
# RoofStyle_PosA              binary           0.0
# RoofStyle_RRAn              binary           1.0
# RoofStyle_RRNn              binary           0.0
# RoofMatl_1Fam               binary           1.0
# RoofMatl_2fmCon             binary           1.0
# RoofMatl_Duplex             binary           0.0
# RoofMatl_Twnhs              binary           0.0
# RoofMatl_TwnhsE             binary           1.0
# Exterior1st_1.5Fin          binary           0.0
# Exterior1st_1.5Unf          binary           0.0
# Exterior1st_1Story          binary           0.0
# Exterior1st_2.5Fin          binary           0.0
# Exterior1st_2.5Unf          binary           1.0
# Exterior1st_2Story          binary           1.0
# Exterior1st_SFoyer          binary           0.0
# Exterior1st_SLvl            binary           1.0
# Exterior2nd_1               binary           0.0
# Exterior2nd_2               binary           1.0
# Exterior2nd_3               binary           1.0
# Exterior2nd_4               binary           1.0
# Exterior2nd_5               binary           1.0
# Exterior2nd_6               binary           0.0
# Exterior2nd_7               binary           1.0
# Exterior2nd_8               binary           0.0
# Exterior2nd_9               binary           0.0
# Exterior2nd_10              binary           1.0
# MasVnrType_2                binary           1.0
# MasVnrType_3                binary           0.0
# MasVnrType_4                binary           0.0
# MasVnrType_5                binary           0.0
# MasVnrType_6                binary           0.0
# MasVnrType_7                binary           1.0
# MasVnrType_8                binary           1.0
# MasVnrType_9                binary           1.0
# Foundation_Flat             binary           1.0
# Foundation_Gable            binary           0.0
# Foundation_Gambrel          binary           0.0
# Foundation_Hip              binary           0.0
# Foundation_Mansard          binary           1.0
# Foundation_Shed             binary           0.0
# BsmtFinType1_CompShg        binary           1.0
# BsmtFinType1_Membran        binary           0.0
# BsmtFinType1_Roll           binary           1.0
# BsmtFinType1_Tar&Grv        binary           0.0
# BsmtFinType1_WdShake        binary           1.0
# BsmtFinType1_WdShngl        binary           0.0
# BsmtFinType2_AsbShng        binary           0.0
# BsmtFinType2_BrkComm        binary           1.0
# BsmtFinType2_BrkFace        binary           0.0
# BsmtFinType2_CemntBd        binary           1.0
# BsmtFinType2_HdBoard        binary           1.0
# BsmtFinType2_MetalSd        binary           0.0
# BsmtFinType2_Plywood        binary           0.0
# BsmtFinType2_Stone          binary           1.0
# BsmtFinType2_Stucco         binary           0.0
# BsmtFinType2_VinylSd        binary           0.0
# BsmtFinType2_Wd Sdng        binary           1.0
# BsmtFinType2_WdShing        binary           0.0
# Heating_AsbShng             binary           0.0
# Heating_Brk Cmn             binary           0.0
# Heating_BrkFace             binary           1.0
# Heating_CmentBd             binary           1.0
# Heating_HdBoard             binary           1.0
# Heating_ImStucc             binary           1.0
# Heating_MetalSd             binary           1.0
# Heating_Other               binary           0.0
# Heating_Plywood             binary           1.0
# Heating_Stone               binary           0.0
# Heating_Stucco              binary           1.0
# Heating_VinylSd             binary           0.0
# Heating_Wd Sdng             binary           0.0
# Heating_Wd Shng             binary           1.0
# CentralAir_BrkTil           binary           0.0
# CentralAir_CBlock           binary           0.0
# CentralAir_PConc            binary           1.0
# CentralAir_Slab             binary           0.0
# CentralAir_Stone            binary           1.0
# CentralAir_Wood             binary           1.0
# Electrical_Floor            binary           1.0
# Electrical_GasA             binary           1.0
# Electrical_GasW             binary           1.0
# Electrical_Grav             binary           0.0
# Electrical_Wall             binary           0.0
# LowQualFinSF_N              binary           0.0
# LowQualFinSF_Y              binary           1.0
# BsmtFullBath_0              binary           0.0
# BsmtFullBath_53             binary           0.0
# BsmtFullBath_80             binary           1.0
# BsmtFullBath_120            binary           0.0
# BsmtFullBath_144            binary           0.0
# BsmtFullBath_156            binary           1.0
# BsmtFullBath_234            binary           1.0
# BsmtFullBath_360            binary           1.0
# BsmtFullBath_384            binary           1.0
# BsmtFullBath_390            binary           0.0
# BsmtFullBath_392            binary           1.0
# BsmtFullBath_397            binary           1.0
# BsmtFullBath_473            binary           0.0
# BsmtFullBath_481            binary           0.0
# BsmtFullBath_514            binary           0.0
# BsmtFullBath_528            binary           1.0
# BsmtFullBath_572            binary           0.0
# BsmtHalfBath_0              binary           0.0
# BsmtHalfBath_1              binary           0.0
# BsmtHalfBath_2              binary           0.0
# BsmtHalfBath_3              binary           1.0
# FullBath_0                  binary           0.0
# FullBath_1                  binary           1.0
# HalfBath_0                  binary           1.0
# HalfBath_1                  binary           1.0
# HalfBath_2                  binary           1.0
# HalfBath_3                  binary           0.0
# BedroomAbvGr_0              binary           0.0
# BedroomAbvGr_1              binary           0.0
# BedroomAbvGr_2              binary           1.0
# KitchenAbvGr_0              binary           0.0
# KitchenAbvGr_1              binary           1.0
# KitchenAbvGr_2              binary           1.0
# KitchenAbvGr_3              binary           0.0
# KitchenAbvGr_4              binary           0.0
# KitchenAbvGr_5              binary           1.0
# KitchenAbvGr_6              binary           1.0
# TotRmsAbvGrd_1              binary           1.0
# TotRmsAbvGrd_2              binary           1.0
# TotRmsAbvGrd_3              binary           0.0
# Functional_2                binary           0.0
# Functional_3                binary           0.0
# Functional_4                binary           1.0
# Functional_5                binary           1.0
# Functional_6                binary           1.0
# Functional_7                binary           0.0
# Functional_8                binary           1.0
# Functional_9                binary           1.0
# Functional_10               binary           0.0
# Functional_11               binary           1.0
# Functional_12               binary           0.0
# Fireplaces_Maj1             binary           1.0
# Fireplaces_Maj2             binary           1.0
# Fireplaces_Min1             binary           0.0
# Fireplaces_Min2             binary           0.0
# Fireplaces_Mod              binary           1.0
# Fireplaces_Sev              binary           0.0
# Fireplaces_Typ              binary           1.0
# GarageType_0                binary           0.0
# GarageType_1                binary           1.0
# GarageType_2                binary           0.0
# GarageType_3                binary           0.0
# GarageCars_0                binary           1.0
# GarageCars_1                binary           0.0
# GarageCars_2                binary           1.0
# GarageCars_3                binary           0.0
# GarageCars_4                binary           0.0
# PavedDrive_N                binary           1.0
# PavedDrive_P                binary           0.0
# PavedDrive_Y                binary           0.0
# 3SsnPorch_0                 binary           1.0
# 3SsnPorch_96                binary           1.0
# 3SsnPorch_140               binary           1.0
# 3SsnPorch_144               binary           0.0
# 3SsnPorch_168               binary           1.0
# 3SsnPorch_180               binary           1.0
# 3SsnPorch_216               binary           1.0
# 3SsnPorch_238               binary           0.0
# 3SsnPorch_290               binary           0.0
# 3SsnPorch_320               binary           0.0
# 3SsnPorch_407               binary           1.0
# 3SsnPorch_508               binary           0.0
# PoolArea_0                  binary           0.0
# PoolArea_512                binary           1.0
# PoolArea_555                binary           0.0
# PoolArea_576                binary           0.0
# PoolArea_738                binary           1.0
# MiscVal_0                   binary           0.0
# MiscVal_54                  binary           0.0
# MiscVal_350                 binary           1.0
# MiscVal_400                 binary           0.0
# MiscVal_450                 binary           1.0
# MiscVal_480                 binary           1.0
# MiscVal_500                 binary           1.0
# MiscVal_560                 binary           0.0
# MiscVal_600                 binary           0.0
# MiscVal_620                 binary           0.0
# MiscVal_700                 binary           0.0
# MiscVal_800                 binary           0.0
# MiscVal_1150                binary           0.0
# MiscVal_1200                binary           0.0
# MiscVal_1300                binary           0.0
# MiscVal_2000                binary           0.0
# MiscVal_3500                binary           1.0
# MiscVal_15500               binary           1.0
# MoSold_M01                  binary           0.0
# MoSold_M02                  binary           0.0
# MoSold_M03                  binary           1.0
# MoSold_M04                  binary           0.0
# MoSold_M05                  binary           0.0
# MoSold_M06                  binary           1.0
# MoSold_M07                  binary           0.0
# MoSold_M08                  binary           0.0
# MoSold_M09                  binary           0.0
# MoSold_M10                  binary           1.0
# MoSold_M11                  binary           1.0
# MoSold_M12                  binary           0.0
# SaleType_COD                binary           1.0
# SaleType_CWD                binary           1.0
# SaleType_Con                binary           1.0
# SaleType_ConLD              binary           1.0
# SaleType_ConLI              binary           1.0
# SaleType_ConLw              binary           0.0
# SaleType_New                binary           1.0
# SaleType_Oth                binary           0.0
# SaleType_WD                 binary           0.0
# SaleCondition_Abnorml       binary           0.0
# SaleCondition_AdjLand       binary           1.0
# SaleCondition_Alloca        binary           1.0
# SaleCondition_Family        binary           1.0
# SaleCondition_Normal        binary           1.0
# SaleCondition_Partial       binary           0.0
# LotFrontage             continuous         129.0
# GarageArea              continuous         884.0
# MasVnrArea              continuous         300.0
# GarageAge               continuous           8.0
# LotArea                 continuous        8158.0
# BsmtFinSF1              continuous         616.0
# BsmtFinSF2              continuous         108.0
# BsmtUnfSF               continuous         292.0
# TotalBsmtSF             continuous        1373.0
# 1stFlrSF                continuous        1007.0
# 2ndFlrSF                continuous         473.0
# GrLivArea               continuous        1536.0
# WoodDeckSF              continuous         550.0
# OpenPorchSF             continuous         166.0
# EnclosedPorch           continuous         202.0
# ScreenPorch             continuous         144.0
# Age                     continuous          47.0
# AgeAfterRemod           continuous          42.0

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

pipeline = Pipeline([
    ("imputer", imputer),
    ("encoder", encoder),
    ("rf", RandomForestRegressor(max_features="auto", random_state=3))
])

param_grid = {"rf__n_estimators": [400, 600, 800], 
              "rf__max_depth": [10, 12, 16]}

rf = GridSearchCV(pipeline, param_grid, cv=5, n_jobs=-1, scoring="neg_root_mean_squared_error", return_train_score=True)

# %%
# %%time
from adhoc.modeling import cv_results_summary

rf.fit(X_train, y_train)
cv_results_summary(rf)
# Out:
# CPU times: user 16 s, sys: 120 ms, total: 16.1 s
# Wall time: 2min 19s
#                  mean_test_score  std_test_score  test_CI_low  test_CI_high  \
# rank_test_score
# 1                      -0.141026        0.007180    -0.149941     -0.132110
# 2                      -0.141148        0.007156    -0.150034     -0.132263
# 3                      -0.141277        0.007037    -0.150015     -0.132539
# 4                      -0.141282        0.007100    -0.150098     -0.132466
# 5                      -0.141286        0.007168    -0.150187     -0.132386
# 6                      -0.141464        0.006878    -0.150004     -0.132923
# 7                      -0.141728        0.007216    -0.150688     -0.132768
# 8                      -0.141794        0.007122    -0.150637     -0.132950
# 9                      -0.141992        0.007032    -0.150724     -0.133260
#
#                  mean_train_score param_rf__max_depth param_rf__n_estimators
# rank_test_score
# 1                       -0.052908                  16                    600
# 2                       -0.053109                  16                    400
# 3                       -0.052980                  16                    800
# 4                       -0.053971                  12                    600
# 5                       -0.054171                  12                    400
# 6                       -0.054076                  12                    800
# 7                       -0.057378                  10                    600
# 8                       -0.057601                  10                    400
# 9                       -0.057510                  10                    800

# %%
#from xgboost import XGBRegressor
#
#pipeline = Pipeline([
#    ("imputer", imputer),
#    ("encoder", encoder),
#    ("xgb", XGBRegressor(learning_rate=0.01, random_state=3))
#])
#
#param_grid = {"xgb__n_estimators": [200, 400, 600], 
#              "xgb__max_depth": [4, 6, 8]}
#
#xgb = GridSearchCV(pipeline, param_grid, cv=5, n_jobs=4, scoring="neg_root_mean_squared_error", return_train_score=True)

# %%
#%%time
#from adhoc.modeling import cv_results_summary
#
#xgb.fit(X_train, y_train)
#cv_results_summary(xgb)

# %% [markdown]
# ## Feature Importance
#
# A feature importance is a technique to measure the impact of a feature on the model performance.
#
# Advantages:
#
# - The feature importance can be used to rank features.
# - We do not underestimate the possibility that a feature has an impact under a combination with another feature.
#
# Disadvantages:
#
# - You need to train a model.
#   - Data processing / feature engineering is required.
# - The feature importance depends not only on the data set, but also on the model.
#   - You can not compare feature importance of different models.

# %% [markdown]
# ### Feature Importance of tree-based models
#
# A tree-based model (decision tree, random forest, etc.) is equipped with its own feature importance.
#
# Given a decision tree, the splitting variable of each node reduces the impurity. We takes the sum of the reduction ([weighted impurity decreasing equation](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html)) by each (splitting) feature as the feature importance. The feature importance of a random forest model is just a (normalized) average of feature importance of the decision trees of the model.

# %%
model = rf.best_estimator_.steps[2][1]
model
# Out:
# RandomForestRegressor(max_depth=16, n_estimators=600, random_state=3)

# %%
pd.Series(model.feature_importances_, index=pd.Series(columns_after_encoding, name="feature"))\
  .sort_values(ascending=False)\
  .rename("feature importance").reset_index().head(10)
# Out:
#         feature  feature importance
# 0     GrLivArea            0.319009
# 1    GarageCond            0.174599
# 2   TotalBsmtSF            0.068732
# 3  GarageCars_3            0.054657
# 4   KitchenQual            0.047332
# 5    GarageArea            0.034302
# 6      BsmtQual            0.033751
# 7      1stFlrSF            0.032652
# 8           Age            0.031011
# 9       LotArea            0.017106

# %% [markdown]
# ### Permutation (feature) importance
#
# (cf. scikit-learn documentation for [Permutation feature importance](https://scikit-learn.org/stable/modules/permutation_importance.html))
#
# In order to measure the impact of a feature, we may drop the feature and train a model of the same architecture/hyperparameters. But this is time/resource consuming. Instead we can permute the values of the features randomly so that the feature pretends to be absent.
#
# Advantages:
#
# - We can apply the algorithm to any trained model.
# - It is easy to implement it. (`sklearn` has an API for it.)
# - (If the model is a scikit-learn pipeline, then we can compute the feature importance of the variable before (one-hot) encoding.)
#
# Disadvantages:
#
# - Not deterministic. We might need to look at confidence intervals in some cases. (But we can increase the number of experiments easily.)
# - We need to have a dev set. i.e. the data set which has the same distribution of the test set, but we are allowed to look at the dataset.

# %%
# %%time
from sklearn.inspection import permutation_importance
p_importance = permutation_importance(rf, X_dev, y_dev, n_repeats=30, n_jobs=4, random_state=9)
# Out:
# CPU times: user 35.2 s, sys: 3.31 s, total: 38.5 s
# Wall time: 1min 39s

# %%
df_fi = pd.DataFrame({
    "feature": X_dev.columns.tolist(),
    "importance": p_importance["importances_mean"]
})
df_fi.sort_values(by="importance", ascending=False, inplace=True)

# %%
from sklearn.metrics import mean_squared_error

rmse_dev = mean_squared_error(y_dev, rf.predict(X_dev), squared=False)
print(f"RMSE on the dev set: {rmse_dev:0.4f}")
# Out:
# RMSE on the dev set: 0.1486

# %% [markdown]
# The following bar chart shows the permutation feature importance. If the bar is orange, then the permutation importance of the corresponding feature is smaller than 1% of the RMSE on the dev set.

# %%
alt.Chart(df_fi)\
   .mark_bar()\
   .encode(x=alt.X("importance:Q"), 
           y=alt.Y("feature:N", sort="-x"),
           tooltip=["feature:N", alt.Tooltip("importance:Q", format="0.5f")],
           color=alt.condition(alt.datum.importance > 0.01*rmse_dev, 
                               alt.value("#1f77b4"), alt.value("#ff7f0e")))\
   .properties(height=1024, title="Permutation feature importance")
# Out:
# alt.Chart(...)

# %%
def scatter_plot(data:pd.DataFrame, field:str, width:int=240) -> alt.Chart:
    chart = alt.Chart(df_dev[[field,target]])\
               .mark_circle()\
               .encode(x=alt.X(field, scale=alt.Scale(zero=False), title=None), 
                       y=alt.Y(target, scale=alt.Scale(type="log"), title=f"Log{target}"))\
               .properties(width=width, title=field)
    return chart

def box_plot(data:pd.DataFrame, field:str, sort:Optional[List[str]]=None, width:int=200, labelAngle:int=0) -> alt.Chart:
    chart = alt.Chart(df_dev[[field,target]])\
                .mark_boxplot()\
                .encode(x=alt.X(f"{field}:N", sort=sort, axis=alt.Axis(labelAngle=labelAngle), title=None),
                        y=alt.Y(target, scale=alt.Scale(type="log")),
                        color=alt.Color("count()", legend=None))\
                .properties(width=width, title=field)
    return chart

# %% [markdown]
# The following diagrams show the relation between the best 3 features and the target variables.

# %%
chart_top1 = scatter_plot(df_dev, "GrLivArea")
chart_top2 = box_plot(df_dev, "ExterQual", sort=["Po","Fa","TA","Gd","Ex"])
chart_top3 = scatter_plot(df_dev, "TotalBsmtSF")

chart_top1 | chart_top2 | chart_top3
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# The following diagrams show the relation between the worst 3 features and the target variables.

# %%
worst1 = box_plot(df_dev, "SaleCondition", labelAngle=90)
worst2 = box_plot(df_dev, "GarageType", labelAngle=90)
worst3 = box_plot(df_dev, "Exterior2nd", width=320, labelAngle=90)

worst1 | worst2 | worst3
# Out:
# alt.HConcatChart(...)

# %%
from adhoc.utilities import bins_by_tree

def BinnedPrediction(data:pd.DataFrame) -> pd.DataFrame:
    df = pd.DataFrame(index=data.index)
    df["GrLivArea"] = bins_by_tree(data, "GrLivArea", target, target_is_continuous=True, n_bins=4)
    df["ExterQual"] = data["ExterQual"]
    df["TotalBsmtSF"] = bins_by_tree(data, "TotalBsmtSF", target, target_is_continuous=True, n_bins=4)
    df["Prediction"] = np.expm1(rf.predict(data.drop(target, axis=1)))
    dg = df.groupby(["GrLivArea","ExterQual","TotalBsmtSF"])["Prediction"].agg(size="size", average="mean").reset_index()
    dg["average"] = np.round(dg["average"])
    return dg

df_binned_pred = BinnedPrediction(df_dev)
OrderGrLivArea = [str(x) for x in df_binned_pred["GrLivArea"].cat.categories]
OrderTotalBsmtSF = list(reversed([str(x) for x in df_binned_pred["TotalBsmtSF"].cat.categories]))

# %% [markdown]
# The following heatmaps show the average of the predictions of regions.

# %%
def heatmap(data:pd.DataFrame, annot:bool=True) -> alt.Chart:
    charts = None
    for exter_qual in ["Fa","TA","Gd","Ex"]:
        base = alt.Chart(data.query("ExterQual == @exter_qual").astype(str))
        heat = base.mark_rect(opacity=0.7)\
                   .encode(x=alt.X("GrLivArea:N", axis=alt.Axis(labelAngle=0), sort=OrderGrLivArea),
                           y=alt.Y("TotalBsmtSF:N", sort=OrderTotalBsmtSF),
                           color=alt.Color("average:Q",
                                           scale=alt.Scale(type="log"), 
                                           title="Prediction"),
                           tooltip=["GrLivArea:N","totalBsmtSF:N","average:Q"])

        text = base.mark_text(fontSize=16)\
                   .encode(x=alt.X("GrLivArea:N", sort=OrderGrLivArea), 
                           y=alt.Y("TotalBsmtSF:N", sort=OrderTotalBsmtSF), 
                           text=alt.Text("average:Q"))
        
        chart = (heat + text).properties(width=600, height=120, title=f"ExterQual = {exter_qual}")
        
        if charts is None:
            charts = chart
        else:
            charts = charts & chart

    return charts

heatmap(df_binned_pred)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## Environment

# %%
# %load_ext watermark
# %watermark -v -n -m -p numpy,scipy,sklearn,pandas,matplotlib,seaborn,altair,torch
# Out:
# Mon Dec 07 2020
#
# CPython 3.7.0
# IPython 7.19.0
#
# numpy 1.19.4
# scipy 1.5.4
# sklearn 0.23.2
# pandas 1.1.4
# matplotlib 3.3.3
# seaborn 0.11.0
# altair 4.1.0
# torch not installed
#
# compiler   : GCC 7.2.0
# system     : Linux
# release    : 4.12.14-lp151.28.83-default
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 8
# interpreter: 64bit
